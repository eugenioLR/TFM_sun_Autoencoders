# %%
import numpy as np
import scipy
import scipy.stats
import pandas as pd
import astropy.units as u
import sunpy.map
import sunpy.visualization.colormaps as cm
import cv2
import skimage
import glob
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
import random

import matplotlib.pyplot as plt
import seaborn as sns
import seaborn_image as isns
sns.set_style("darkgrid")

# %matplotlib inline

import tensorflow as tf
from tensorflow import keras
from keras import layers

tf.distribute.MirroredStrategy()


import autoenc_model as aem
import data_generator as dg
import utils
# Out:
# 2023-04-14 23:11:15.710220: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# 2023-04-14 23:11:16.497455: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.497588: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.507581: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.507717: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.507803: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.507882: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.593608: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.593725: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.593810: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.593905: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.593984: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.594067: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.975977: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.976107: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.976200: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.976281: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.976360: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.976442: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7416 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-04-14 23:11:16.976723: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 23:11:16.976803: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 6142 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:08:00.0, compute capability: 8.6
# 2023-04-14 23:11:16.977003: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# /home/eugeniolr/.local/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.8.0 and strictly below 2.11.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
batch_size = 50
gen_input = dg.SunImgAE3CGenerator("data/composite_data_polar/", batch_size, test_split=0.2, shuffle=True, noise_filter=True)

# %%
img_amount = 3

sample_images = gen_input.sample(img_amount)

image_list = []
for data_image in sample_images:
    for channel in data_image.transpose(2,0,1):
        image_list.append(channel)

isns.ImageGrid(image_list, cmap=["sdoaia193", "sdoaia211", "seismic"]*img_amount, orientation="h", vmin=0, vmax=1)

# %%
print(utils.polar_to_linear(image_list[0]).shape, image_list[0].shape)
ax = isns.ImageGrid(image_list.copy(), col_wrap=3, cmap=["sdoaia193", "sdoaia211", "seismic"]*img_amount, map_func=utils.polar_to_linear, orientation="h", vmin=0, vmax=1)
# Out:
# (200, 200) (100, 360)

# %%
latent_size = 64
# optimizer = keras.optimizers.Adam(learning_rate=0.001)
# optimizer = keras.optimizers.SGD(learning_rate=0.01)
optimizer = keras.optimizers.RMSprop(learning_rate=0.001)

loss_fn = "mse"

autoencoder, encoder, decoder = aem.gen_xception_autoenc_3c(latent_size, optim=optimizer, loss=loss_fn)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 100, 360, 3  0           []
#                                 )]
#
#  cylindrical_padding2d_1 (Cylin  (None, 100, 366, 3)  0          ['input_3[0][0]']
#  dricalPadding2D)
#
#  conv2d_11 (Conv2D)             (None, 49, 182, 32)  864         ['cylindrical_padding2d_1[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 49, 182, 32)  128        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 49, 182, 32)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 47, 180, 64)  18432       ['activation_33[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 47, 180, 64)  256        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 47, 180, 64)  0           ['batch_normalization_41[0][0]']
#
#  separable_conv2d_34 (Separable  (None, 47, 180, 128  8768       ['activation_34[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_43 (BatchN  (None, 47, 180, 128  512        ['separable_conv2d_34[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 47, 180, 128  0           ['batch_normalization_43[0][0]']
#                                 )
#
#  separable_conv2d_35 (Separable  (None, 47, 180, 128  17536      ['activation_35[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_44 (BatchN  (None, 47, 180, 128  512        ['separable_conv2d_35[0][0]']
#  ormalization)                  )
#
#  conv2d_13 (Conv2D)             (None, 24, 90, 128)  8192        ['activation_34[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 24, 90, 128)  0          ['batch_normalization_44[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 24, 90, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 24, 90, 128)  0           ['max_pooling2d_4[0][0]',
#                                                                   'batch_normalization_42[0][0]']
#
#  separable_conv2d_36 (Separable  (None, 24, 90, 256)  33920      ['add_12[0][0]']
#  Conv2D)
#
#  batch_normalization_46 (BatchN  (None, 24, 90, 256)  1024       ['separable_conv2d_36[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 24, 90, 256)  0           ['batch_normalization_46[0][0]']
#
#  separable_conv2d_37 (Separable  (None, 24, 90, 256)  67840      ['activation_36[0][0]']
#  Conv2D)
#
#  batch_normalization_47 (BatchN  (None, 24, 90, 256)  1024       ['separable_conv2d_37[0][0]']
#  ormalization)
#
#  conv2d_14 (Conv2D)             (None, 12, 45, 256)  32768       ['add_12[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 12, 45, 256)  0          ['batch_normalization_47[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 12, 45, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 12, 45, 256)  0           ['max_pooling2d_5[0][0]',
#                                                                   'batch_normalization_45[0][0]']
#
#  separable_conv2d_38 (Separable  (None, 12, 45, 728)  188672     ['add_13[0][0]']
#  Conv2D)
#
#  batch_normalization_49 (BatchN  (None, 12, 45, 728)  2912       ['separable_conv2d_38[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 12, 45, 728)  0           ['batch_normalization_49[0][0]']
#
#  separable_conv2d_39 (Separable  (None, 12, 45, 728)  536536     ['activation_37[0][0]']
#  Conv2D)
#
#  batch_normalization_50 (BatchN  (None, 12, 45, 728)  2912       ['separable_conv2d_39[0][0]']
#  ormalization)
#
#  conv2d_15 (Conv2D)             (None, 6, 23, 728)   186368      ['add_13[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 6, 23, 728)  0           ['batch_normalization_50[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 6, 23, 728)  2912        ['conv2d_15[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 6, 23, 728)   0           ['max_pooling2d_6[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  activation_38 (Activation)     (None, 6, 23, 728)   0           ['add_14[0][0]']
#
#  separable_conv2d_40 (Separable  (None, 6, 23, 728)  536536      ['activation_38[0][0]']
#  Conv2D)
#
#  batch_normalization_51 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_40[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_51[0][0]']
#
#  separable_conv2d_41 (Separable  (None, 6, 23, 728)  536536      ['activation_39[0][0]']
#  Conv2D)
#
#  batch_normalization_52 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_41[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_52[0][0]']
#
#  separable_conv2d_42 (Separable  (None, 6, 23, 728)  536536      ['activation_40[0][0]']
#  Conv2D)
#
#  batch_normalization_53 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_42[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 6, 23, 728)   0           ['batch_normalization_53[0][0]',
#                                                                   'add_14[0][0]']
#
#  activation_41 (Activation)     (None, 6, 23, 728)   0           ['add_15[0][0]']
#
#  separable_conv2d_43 (Separable  (None, 6, 23, 728)  536536      ['activation_41[0][0]']
#  Conv2D)
#
#  batch_normalization_54 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_43[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_54[0][0]']
#
#  separable_conv2d_44 (Separable  (None, 6, 23, 728)  536536      ['activation_42[0][0]']
#  Conv2D)
#
#  batch_normalization_55 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_44[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_55[0][0]']
#
#  separable_conv2d_45 (Separable  (None, 6, 23, 728)  536536      ['activation_43[0][0]']
#  Conv2D)
#
#  batch_normalization_56 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_45[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 6, 23, 728)   0           ['batch_normalization_56[0][0]',
#                                                                   'add_15[0][0]']
#
#  activation_44 (Activation)     (None, 6, 23, 728)   0           ['add_16[0][0]']
#
#  separable_conv2d_46 (Separable  (None, 6, 23, 728)  536536      ['activation_44[0][0]']
#  Conv2D)
#
#  batch_normalization_57 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_46[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_57[0][0]']
#
#  separable_conv2d_47 (Separable  (None, 6, 23, 728)  536536      ['activation_45[0][0]']
#  Conv2D)
#
#  batch_normalization_58 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_47[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_58[0][0]']
#
#  separable_conv2d_48 (Separable  (None, 6, 23, 728)  536536      ['activation_46[0][0]']
#  Conv2D)
#
#  batch_normalization_59 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_48[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 6, 23, 728)   0           ['batch_normalization_59[0][0]',
#                                                                   'add_16[0][0]']
#
#  activation_47 (Activation)     (None, 6, 23, 728)   0           ['add_17[0][0]']
#
#  separable_conv2d_49 (Separable  (None, 6, 23, 728)  536536      ['activation_47[0][0]']
#  Conv2D)
#
#  batch_normalization_60 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_49[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_60[0][0]']
#
#  separable_conv2d_50 (Separable  (None, 6, 23, 728)  536536      ['activation_48[0][0]']
#  Conv2D)
#
#  batch_normalization_61 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_50[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_61[0][0]']
#
#  separable_conv2d_51 (Separable  (None, 6, 23, 728)  536536      ['activation_49[0][0]']
#  Conv2D)
#
#  batch_normalization_62 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_51[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 6, 23, 728)   0           ['batch_normalization_62[0][0]',
#                                                                   'add_17[0][0]']
#
#  activation_50 (Activation)     (None, 6, 23, 728)   0           ['add_18[0][0]']
#
#  separable_conv2d_52 (Separable  (None, 6, 23, 728)  536536      ['activation_50[0][0]']
#  Conv2D)
#
#  batch_normalization_63 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_52[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_63[0][0]']
#
#  separable_conv2d_53 (Separable  (None, 6, 23, 728)  536536      ['activation_51[0][0]']
#  Conv2D)
#
#  batch_normalization_64 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_53[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_64[0][0]']
#
#  separable_conv2d_54 (Separable  (None, 6, 23, 728)  536536      ['activation_52[0][0]']
#  Conv2D)
#
#  batch_normalization_65 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_54[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 6, 23, 728)   0           ['batch_normalization_65[0][0]',
#                                                                   'add_18[0][0]']
#
#  activation_53 (Activation)     (None, 6, 23, 728)   0           ['add_19[0][0]']
#
#  separable_conv2d_55 (Separable  (None, 6, 23, 728)  536536      ['activation_53[0][0]']
#  Conv2D)
#
#  batch_normalization_66 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_55[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_66[0][0]']
#
#  separable_conv2d_56 (Separable  (None, 6, 23, 728)  536536      ['activation_54[0][0]']
#  Conv2D)
#
#  batch_normalization_67 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_56[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_67[0][0]']
#
#  separable_conv2d_57 (Separable  (None, 6, 23, 728)  536536      ['activation_55[0][0]']
#  Conv2D)
#
#  batch_normalization_68 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_57[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 6, 23, 728)   0           ['batch_normalization_68[0][0]',
#                                                                   'add_19[0][0]']
#
#  activation_56 (Activation)     (None, 6, 23, 728)   0           ['add_20[0][0]']
#
#  separable_conv2d_58 (Separable  (None, 6, 23, 728)  536536      ['activation_56[0][0]']
#  Conv2D)
#
#  batch_normalization_69 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_58[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_69[0][0]']
#
#  separable_conv2d_59 (Separable  (None, 6, 23, 728)  536536      ['activation_57[0][0]']
#  Conv2D)
#
#  batch_normalization_70 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_59[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_70[0][0]']
#
#  separable_conv2d_60 (Separable  (None, 6, 23, 728)  536536      ['activation_58[0][0]']
#  Conv2D)
#
#  batch_normalization_71 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_60[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 6, 23, 728)   0           ['batch_normalization_71[0][0]',
#                                                                   'add_20[0][0]']
#
#  activation_59 (Activation)     (None, 6, 23, 728)   0           ['add_21[0][0]']
#
#  separable_conv2d_61 (Separable  (None, 6, 23, 728)  536536      ['activation_59[0][0]']
#  Conv2D)
#
#  batch_normalization_72 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_61[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_72[0][0]']
#
#  separable_conv2d_62 (Separable  (None, 6, 23, 728)  536536      ['activation_60[0][0]']
#  Conv2D)
#
#  batch_normalization_73 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_62[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 6, 23, 728)   0           ['batch_normalization_73[0][0]']
#
#  separable_conv2d_63 (Separable  (None, 6, 23, 728)  536536      ['activation_61[0][0]']
#  Conv2D)
#
#  batch_normalization_74 (BatchN  (None, 6, 23, 728)  2912        ['separable_conv2d_63[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 6, 23, 728)   0           ['batch_normalization_74[0][0]',
#                                                                   'add_21[0][0]']
#
#  activation_62 (Activation)     (None, 6, 23, 728)   0           ['add_22[0][0]']
#
#  separable_conv2d_64 (Separable  (None, 6, 23, 256)  192920      ['activation_62[0][0]']
#  Conv2D)
#
#  batch_normalization_76 (BatchN  (None, 6, 23, 256)  1024        ['separable_conv2d_64[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 6, 23, 256)   0           ['batch_normalization_76[0][0]']
#
#  separable_conv2d_65 (Separable  (None, 6, 23, 256)  67840       ['activation_63[0][0]']
#  Conv2D)
#
#  batch_normalization_77 (BatchN  (None, 6, 23, 256)  1024        ['separable_conv2d_65[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 3, 12, 256)   186368      ['add_22[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 3, 12, 256)  0           ['batch_normalization_77[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 3, 12, 256)  1024        ['conv2d_16[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 3, 12, 256)   0           ['max_pooling2d_7[0][0]',
#                                                                   'batch_normalization_75[0][0]']
#
#  separable_conv2d_66 (Separable  (None, 3, 12, 1536)  395520     ['add_23[0][0]']
#  Conv2D)
#
#  batch_normalization_78 (BatchN  (None, 3, 12, 1536)  6144       ['separable_conv2d_66[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 3, 12, 1536)  0           ['batch_normalization_78[0][0]']
#
#  separable_conv2d_67 (Separable  (None, 3, 12, 2048)  3159552    ['activation_64[0][0]']
#  Conv2D)
#
#  batch_normalization_79 (BatchN  (None, 3, 12, 2048)  8192       ['separable_conv2d_67[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 3, 12, 2048)  0           ['batch_normalization_79[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['activation_65[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 64)           131136      ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 18,211,120
# Trainable params: 18,160,608
# Non-trainable params: 50,512
# __________________________________________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 64)]              0
#
#  dense_3 (Dense)             (None, 1024)              66560
#
#  reshape_1 (Reshape)         (None, 16, 16, 4)         0
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 64)        2368
#
#  conv2d_transpose_5 (Conv2DT  (None, 32, 32, 64)       36928
#  ranspose)
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 32)        18464
#
#  conv2d_transpose_6 (Conv2DT  (None, 64, 64, 64)       18496
#  ranspose)
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 16)        9232
#
#  conv2d_transpose_7 (Conv2DT  (None, 128, 128, 32)     4640
#  ranspose)
#
#  conv2d_20 (Conv2D)          (None, 128, 128, 8)       2312
#
#  conv2d_transpose_8 (Conv2DT  (None, 128, 256, 3)      219
#  ranspose)
#
#  conv2d_21 (Conv2D)          (None, 128, 256, 8)       224
#
#  conv2d_transpose_9 (Conv2DT  (None, 128, 512, 3)      219
#  ranspose)
#
#  cropping2d_1 (Cropping2D)   (None, 100, 360, 3)       0
#
# =================================================================
# Total params: 159,662
# Trainable params: 159,662
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 100, 360, 3)]     0
#
#  model_3 (Functional)        (None, 64)                18211120
#
#  model_4 (Functional)        (None, 100, 360, 3)       159662
#
# =================================================================
# Total params: 18,370,782
# Trainable params: 18,320,270
# Non-trainable params: 50,512
# _________________________________________________________________

# %%
n_epochs = 125

history = autoencoder.fit(gen_input, epochs=n_epochs)
# Out:
# Epoch 1/125
# 2023-04-14 23:12:08.699224: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
#  22/281 [=>............................] - ETA: 53s - loss: 0.0383 - mae: 0.1271
# 2023-04-14 23:12:32.497071: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 128.00MiB (rounded to 134217728)requested by op model_5/model_4/conv2d_transpose_7/conv2d_transpose
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-04-14 23:12:32.497175: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2023-04-14 23:12:32.497182: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 171, Chunks in use: 169. 42.8KiB allocated for chunks. 42.2KiB in use in bin. 13.3KiB client-requested in use in bin.
# 2023-04-14 23:12:32.497187: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 48, Chunks in use: 48. 25.2KiB allocated for chunks. 25.2KiB in use in bin. 24.0KiB client-requested in use in bin.
# 2023-04-14 23:12:32.497191: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 112, Chunks in use: 112. 116.2KiB allocated for chunks. 116.2KiB in use in bin. 109.7KiB client-requested in use in bin.
# 2023-04-14 23:12:32.497196: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 402, Chunks in use: 401. 1.18MiB allocated for chunks. 1.18MiB in use in bin. 1.11MiB client-requested in use in bin.
# 2023-04-14 23:12:32.497200: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 72, Chunks in use: 72. 353.5KiB allocated for chunks. 353.5KiB in use in bin. 278.7KiB client-requested in use in bin.
# 2023-04-14 23:12:32.497204: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 48, Chunks in use: 46. 440.0KiB allocated for chunks. 420.0KiB in use in bin. 398.0KiB client-requested in use in bin.
# 2023-04-14 23:12:32.497208: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 119, Chunks in use: 119. 2.96MiB allocated for chunks. 2.96MiB in use in bin. 2.92MiB client-requested in use in bin.
# 2023-04-14 23:12:32.497212: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 38, Chunks in use: 38. 1.55MiB allocated for chunks. 1.55MiB in use in bin. 1.20MiB client-requested in use in bin.
# 2023-04-14 23:12:32.497215: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 20, Chunks in use: 20. 1.47MiB allocated for chunks. 1.47MiB in use in bin. 1.37MiB client-requested in use in bin.
# 2023-04-14 23:12:32.497219: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 15, Chunks in use: 15. 2.02MiB allocated for chunks. 2.02MiB in use in bin. 1.95MiB client-requested in use in bin.
# 2023-04-14 23:12:32.497223: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 17, Chunks in use: 17. 4.81MiB allocated for chunks. 4.81MiB in use in bin. 4.25MiB client-requested in use in bin.
# 2023-04-14 23:12:32.497227: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 21, Chunks in use: 21. 14.31MiB allocated for chunks. 14.31MiB in use in bin. 13.66MiB client-requested in use in bin.
# 2023-04-14 23:12:32.497231: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 9, Chunks in use: 9. 12.37MiB allocated for chunks. 12.37MiB in use in bin. 9.55MiB client-requested in use in bin.
# 2023-04-14 23:12:32.497236: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 129, Chunks in use: 129. 284.86MiB allocated for chunks. 284.86MiB in use in bin. 261.19MiB client-requested in use in bin.
# 2023-04-14 23:12:32.497240: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 2, Chunks in use: 2. 8.02MiB allocated for chunks. 8.02MiB in use in bin. 6.02MiB client-requested in use in bin.
# 2023-04-14 23:12:32.497244: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 13, Chunks in use: 13. 151.31MiB allocated for chunks. 151.31MiB in use in bin. 139.62MiB client-requested in use in bin.
# 2023-04-14 23:12:32.497248: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 78, Chunks in use: 78. 1.83GiB allocated for chunks. 1.83GiB in use in bin. 1.83GiB client-requested in use in bin.
# 2023-04-14 23:12:32.497252: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks:
I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 7776698368 memory_limit_: 7776698368 available bytes: 0 curr_region_allocation_bytes_: 15553396736
# 2023-04-14 23:12:32.502969: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      7776698368
# InUse:                      7736667392
# MaxInUse:                   7736668160
# NumAllocs:                       41348
# MaxAllocSize:                956301312
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-04-14 23:12:32.503011: W tensorflow/tsl/framework/bfc_allocator.cc:497] ************************************************************x**************************************x
# 2023-04-14 23:12:32.503036: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at conv_grad_input_ops.cc:409 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[64,32,128,128] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2023-04-14 23:12:32.503069: I tensorflow/core/common_runtime/executor.cc:1197] [/job:localhost/replica:0/task:0/device:GPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[64,32,128,128] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model_5/model_4/conv2d_transpose_7/conv2d_transpose}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[11], line 3
#       1 n_epochs = 125
# ----> 3 history = autoencoder.fit(gen_input, epochs=n_epochs)
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /usr/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'model_5/model_4/conv2d_transpose_7/conv2d_transpose' defined at (most recent call last):
#     File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/usr/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/usr/lib/python3.10/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#       app.start()
#     File "/usr/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 725, in start
#       self.io_loop.start()
#     File "/usr/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#       self._run_once()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#       handle._run()
#     File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/usr/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "/usr/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "/usr/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "/usr/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "/usr/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/usr/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/usr/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3006, in run_cell
#       result = self._run_cell(
#     File "/usr/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3061, in _run_cell
#       result = runner(coro)
#     File "/usr/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/usr/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3266, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/usr/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3445, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/usr/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_13764/3589024435.py", line 3, in <module>
#       history = autoencoder.fit(gen_input, epochs=n_epochs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/engine/base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/layers/convolutional/conv2d_transpose.py", line 296, in call
#       outputs = backend.conv2d_transpose(
#     File "/home/eugeniolr/.local/lib/python3.10/site-packages/keras/backend.py", line 6119, in conv2d_transpose
#       x = tf.compat.v1.nn.conv2d_transpose(
# Node: 'model_5/model_4/conv2d_transpose_7/conv2d_transpose'
# OOM when allocating tensor with shape[64,32,128,128] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model_5/model_4/conv2d_transpose_7/conv2d_transpose}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_31871]

# %%
autoencoder.save("autoencoder_xception.h5")
encoder.save("encoder_xception.h5")
decoder.save("decoder_xception.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
gen_input.training = False
autoencoder.evaluate(gen_input)
plt.plot(history.history['loss'], label='loss')
# plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
# Out:
# 2023-04-07 22:02:15.119784: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 359/359 [==============================] - 83s 227ms/step - loss: 0.0014 - mae: 0.0177

# %%
# test_img = np.array(random.choices(input_test, k=1))
test_img = gen_input.sample(1)

test_img_display = test_img[0].copy()
test_img_display[:,:,2] = np.abs((0.5 - test_img_display[:,:,2])*2)
isns.imgplot(test_img_display)
isns.rgbplot(test_img[0], cmap=["sdoaia193", "sdoaia211", "seismic"], vmin=0, vmax=1)

# %%
code = encoder(test_img)
# isns.imgplot(np.reshape(code[0], (6, 8)))
isns.imgplot(np.reshape(code[0], (8, 8)))
# Out:
# <AxesSubplot: >

# %%
decoded = decoder(code)
decoded_display = np.copy(decoded[0])
decoded_display[:,:,2] = np.abs((0.5 - decoded_display[:,:,2])*2)
isns.imgplot(decoded_display)
isns.rgbplot(decoded[0], cmap=["sdoaia193", "sdoaia211", "seismic"], vmin=0, vmax=1)

# %%
test_img_channels = [i for i in test_img[0].transpose(2,0,1)]

decoded_img_channels = [i for i in np.asarray(decoded[0]).transpose(2,0,1)]


isns.ImageGrid(test_img_channels+decoded_img_channels, cmap=["sdoaia193", "sdoaia211", "seismic"]*2, vmin=0, vmax=1, map_func=utils.polar_to_linear)
